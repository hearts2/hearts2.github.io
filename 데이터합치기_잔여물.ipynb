# %% [markdown]
# <a href="https://colab.research.google.com/github/hearts2/hearts2.github.io/blob/master/%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%95%A9%EC%B9%98%EA%B8%B0_%EC%9E%94%EC%97%AC%EB%AC%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats # 통계 함수 사용
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/전처리용/이상치1.5.xlsx', thousands=',')
data.head(1)
# Out:
#    자치구      동         시설명     연면적  주변특성  대중교통  동별전체인구  60세~  60세~/전체인구  \
# 0  종로구  청운효자동  청운효자동 주민센터  965.52     0     1   11978  2945   0.245867
#
#    60세~/구별전체             비율  디지털정보지수
# 0   0.075281  336867.539821  2933.53

# %%
data.shape
# Out:
# (501, 12)

# %%
sta9 = data.iloc[:,0:3]
sta9.head(1)
# Out:
#    자치구      동         시설명
# 0  종로구  청운효자동  청운효자동 주민센터

# %%
# 연면적
area = data.iloc[:,3]
area.head(1)
# Out:
# 0    965.52
# Name: 연면적, dtype: float64

# %%
# 주변특성
near = data.iloc[:,9] + data.iloc[:,10] + data.iloc[:,11] + data.iloc[:,12]
near.head(3)
# Out:
# 0    0.0
# 1    3.0
# 2    4.0
# dtype: float64

# %%
# 대중교통
public = data.iloc[:,13] + data.iloc[:,14]
public.head(3)
# Out:
# 0    1.0
# 1    1.0
# 2    5.0
# dtype: float64

# %%
sta9 = pd.concat([sta9, area, near, public],axis = 1)
sta9.head(1)
# Out:
#    자치구      동         시설명     연면적    0    1
# 0  종로구  청운효자동  청운효자동 주민센터  965.52  0.0  1.0

# %%
# 나머지
for i in range(15,23):
    a = data.iloc[:,i]
    sta9 = pd.concat([sta9, a],axis = 1)
sta9.head(1)
# Out:
#    자치구      동         시설명     연면적    0    1   동별전체인구    60세~  60세~/전체인구  \
# 0  종로구  청운효자동  청운효자동 주민센터  965.52  0.0  1.0  11978.0  2945.0  24.586742
#
#     구별전체인구  60세~/구별전체          보행인구            비율  디지털정보지수
# 0  39120.0  13.283531  4.474791e+06  5.944102e+07  2933.53

# %%
sta9 = sta9.rename(columns={0:'주변특성'})
sta9 = sta9.rename(columns={1:'대중교통'})
sta9.head(3)
# Out:
#    자치구            동           시설명      연면적  주변특성  대중교통   동별전체인구    60세~  \
# 0  종로구        청운효자동    청운효자동 주민센터   965.52   0.0   1.0  11978.0  2945.0
# 1  종로구          사직동      사직동 주민센터   346.65   3.0   1.0   9372.0  2468.0
# 2  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  1981.09   4.0   5.0   7197.0  2682.0
#
#    60세~/전체인구   구별전체인구  60세~/구별전체          보행인구            비율  디지털정보지수
# 0  24.586742  39120.0  13.283531  4.474791e+06  5.944102e+07  2933.53
# 1  26.333760  39120.0  15.850891  4.474791e+06  7.092942e+07  2406.94
# 2  37.265527  39120.0  14.586130  4.474791e+06  6.526988e+07  2305.52

# %%
# 엑셀로 저장
# sta9.to_excel('주민센터 - 스테나인 전용.xlsx')

# %% [markdown]
# # K-means 잔여물

# %%
stanine46over.head(1)
# Out:
#    자치구            동           시설명      연면적  주변특성  대중교통  동별전체인구  60세~  \
# 2  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  1981.09     4     5    7197  2682
#
#    60세~/전체인구  60세~/구별전체             비율  디지털정보지수  총합 9
# 2   0.372655   0.068558  306783.953096  2305.52  49.0

# %%
stanine46num = stanine46over.iloc[:,3:-1]
stanine46num.head(1)
# Out:
#        연면적  주변특성  대중교통  동별전체인구  60세~  60세~/전체인구  60세~/구별전체             비율  \
# 2  1981.09     4     5    7197  2682   0.372655   0.068558  306783.953096
#
#    디지털정보지수
# 2  2305.52

# %%
column = stanine46num.columns
column
# Out:
# Index(['연면적', '주변특성', '대중교통', '동별전체인구', '60세~', '60세~/전체인구', '60세~/구별전체', '비율',
#        '디지털정보지수'],
#       dtype='object')

# %%
scaler = StandardScaler()
dfstan2 = scaler.fit_transform(stanine46num)
dfstan2 = pd.DataFrame(dfstan2, columns = column)
dfstan2.head(1)
# Out:
#         연면적      주변특성      대중교통    동별전체인구      60세~  60세~/전체인구  60세~/구별전체  \
# 0 -0.136973  2.055109  1.768897 -2.569266 -2.520414   2.325439  -0.370698
#
#         비율   디지털정보지수
# 0 -1.30219 -2.647896

# %%
dfstan2 = dfstan2.iloc[:,0:3]
dfstan2.head(1)
# Out:
#         연면적      주변특성     대중교통
# 0  1.886937 -0.312585  1.13372
